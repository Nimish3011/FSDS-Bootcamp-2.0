# %%
import pandas as pd

# %% [markdown]
# Files :
#
#     sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv
#     Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
#     excel file - https://github.com/finbourne/sample-excel

# %%
ls
# Out:
#  Volume in drive E is Media
#  Volume Serial Number is 7293-E2F1
#
#  Directory of e:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook
#
# 05/04/2023  03:59 PM    <DIR>          .
# 05/04/2023  03:59 PM    <DIR>          ..
# 05/04/2023  03:41 PM           289,880 FSDS_1.0_Pandas_Day1_262.ipynb
# 05/04/2023  03:59 PM    <DIR>          Resources
# 05/01/2023  03:20 PM       574,072,999 zomato.csv
#                2 File(s)    574,362,879 bytes
#                3 Dir(s)  154,677,428,224 bytes free

# %%
pd.read_csv('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Python\Pandas\pokemon_data.csv')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pd.read_csv("E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\locations.csv")
# Out:
#     id  organization_id                                      accessibility
# 0    1                1       disabled_parking, ramp, restroom, wheelchair  \
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\services.csv')
# Out:
#     id  location_id  program_id         accepted_payments
# 0    1            1         NaN                       NaN  \
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
import pandas as pd
pd.read_csv("taxonomy.csv")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df = pd.read_csv('taxonomy.csv')

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('taxonomy.csv',header=None)
# Out:
#                0                             1          2
# 0    taxonomy_id                          name  parent_id  \
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
pd.read_csv('taxonomy.csv',names =['abc','b','c','d','e'])
# Out:
#              abc                             b          c
# 0    taxonomy_id                          name  parent_id  \
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d   e
# 0             parent_name NaN
# 1                     NaN NaN
# 2               Emergency NaN
# 3               Emergency NaN
# 4          Emergency Cash NaN
# ..                    ...  ..
# 286  Advocacy & Legal Aid NaN
# ...

# %%
pd.read_csv('taxonomy.csv',names =['abc','b']) #applied to, from left to right.
# Out:
#                                                 abc                     b
# taxonomy_id name                          parent_id           parent_name
# 101         Emergency                           NaN                   NaN
# 101-01      Disaster Response                   101             Emergency
# 101-02      Emergency Cash                      101             Emergency
# 101-02-01   Help Pay for Food                101-02        Emergency Cash
# ...                                             ...                   ...
# 111-01-07   Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02      Mediation                           111                 Legal
# 111-03      Notary                              111                 Legal
# 111-04      Representation                      111                 Legal
# 111-05      Translation & Interpretation        111                 Legal
#
# [291 rows x 2 columns]

# %%
pd.read_csv('taxonomy.csv' ,names=["adfgfadssaf" , 'b' ] )
# Out:
#                                        adfgfadssaf                     b
# 101       Emergency                            NaN                   NaN
# 101-01    Disaster Response                    101             Emergency
# 101-02    Emergency Cash                       101             Emergency
# 101-02-01 Help Pay for Food                 101-02        Emergency Cash
# 101-02-02 Help Pay for Healthcare           101-02        Emergency Cash
# ...                                            ...                   ...
# 111-01-07 Workplace Rights                  111-01  Advocacy & Legal Aid
# 111-02    Mediation                            111                 Legal
# 111-03    Notary                               111                 Legal
# 111-04    Representation                       111                 Legal
# 111-05    Translation & Interpretation         111                 Legal
#
# [290 rows x 2 columns]

# %%
pd.read_csv('sample_test.csv')
# Out:
#        name                 emailid    address  pin code         sirname
# 0  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore     560085          kumar
# 1     krish         krish@gmail.com  bengalore     560085           naik
# 2    ineuron     ineuron@ineuron.ai  Bengalore     560085  intelligence
# 3     pandas      pandas@ineuron.ai    chennai   25845121       tutorial

# %%
pd.read_csv('sample_test.csv',sep='@')
# Out:
#                  name      emailid    address  pin code         sirname
# sudhanshu  SSKUMAR9876   GMAIL.COM  Bengalore     560085          kumar
# krish            krish   gmail.com  bengalore     560085           naik
# ineuron        ineuron  ineuron.ai  Bengalore     560085  intelligence
# pandas          pandas  ineuron.ai    chennai   25845121       tutorial

# %%
df = pd.read_csv('sample_test.csv',sep='|')

# %%
df
# Out:
#        name                 emailid    address  pin code         sirname
# 0  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore     560085          kumar
# 1     krish         krish@gmail.com  bengalore     560085           naik
# 2    ineuron     ineuron@ineuron.ai  Bengalore     560085  intelligence
# 3     pandas      pandas@ineuron.ai    chennai   25845121       tutorial

# %%
pd.read_csv('taxonomy.csv',sep=',' , skiprows=[1,4])
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0        101-01             Disaster Response       101             Emergency
# 1        101-02                Emergency Cash       101             Emergency
# 2     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 3     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# 4     101-02-04              Help Pay for Gas    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 283   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 284      111-02                     Mediation       111                 Legal
# 285      111-03                        Notary       111                 Legal
# 286      111-04                Representation       111                 Legal
# 287      111-05  Translation & Interpretation       111                 Legal
#
# [288 rows x 4 columns]

# %%
pd.read_csv('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\mail_addresses.csv',sep=',' , skiprows=[2,3])
# Out:
#     id  location_id                            attention
# 0    1            1   Fair Oaks Intergenerational Center  \
# 1    4            4         PFS Family Visitation Center
# 2    5            5  Economic Self - Sufficiency Program
# 3    6            6                         Little House
# 4    7            7                        Rosener House
# 5    8            8       Meals on Wheels - South County
# 6    9            9                     Fair Oaks Branch
# 7   10           10                         Main Library
# 8   11           11                      Schaberg Branch
# 9   12           12                         Project Read
# 10  13           13                Redwood Shores Branch
# 11  14           14                       Salvation Army
# 12  15           15          Adult Rehabilitation Center
# 13  16           16                       Salvation Army
# 14  17           17                       Salvation Army
# ...

# %%
df1 = pd.read_csv('sample_test.csv',sep='|' , skiprows=[1,3])

# %%
df1
# Out:
#     name             emailid    address  pin code    sirname
# 0  krish     krish@gmail.com  bengalore     560085      naik
# 1  pandas  pandas@ineuron.ai    chennai   25845121  tutorial

# %%
df = pd.read_csv('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\services.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments
# 0    1            1         NaN                       NaN  \
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name
# 0   1            1         NaN               NaN            NaN  \
# 1   2            2         NaN               NaN            NaN
#
#                   application_process
# 0          Walk in or apply by phone.  \
# 1  Apply by phone for an appointment.
#
#                                             audience
# 0  Older adults age 55 or over, ethnic minorities...  \
# 1       Residents of San Mateo County age 55 or over
#
#                                          description
# 0  A walk-in center for older adults that provide...  \
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...  \
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords
# ...

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name
# 0   1            1         NaN               NaN            NaN  \
# 1   2            2         NaN               NaN            NaN
#
#                   application_process
# 0          Walk in or apply by phone.  \
# 1  Apply by phone for an appointment.
#
#                                             audience
# 0  Older adults age 55 or over, ethnic minorities...  \
# 1       Residents of San Mateo County age 55 or over
#
#                                          description
# 0  A walk-in center for older adults that provide...  \
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...  \
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments
# 20  21           21         NaN                       NaN  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process
# 20                    NaN    By phone during business hours.  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience
# 20                                                NaN  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility
# 20                                just a test service         NaN  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN
# ...

# %%
df.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments
# 21  22           22         NaN  Cash, Check, Credit Card  \
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process
# 21  Fotos para pasaportes  Walk in or apply by phone or mail  \
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience
# 21  Profit and nonprofit businesses, the public, m...  \
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN  \
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...         NaN
#
#                     email  ...
# 21  passports@example.org  ...  \
# 22                    NaN  ...
#
#                               interpretation_services
# 21  We offer 3-way interpretation services over th...  \
# ...

# %%
df. columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
for i in df. columns:
    print(i)
# Out:
# id
# location_id
# program_id
# accepted_payments
# alternate_name
# application_process
# audience
# description
# eligibility
# email
# fees
# funding_sources
# interpretation_services
# keywords
# languages
# name
# required_documents
# service_areas
# status
# wait_time
# website
# taxonomy_ids

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['name']
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
df["keywords"]
# Out:
# 0     ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1     EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2     Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3     INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4        COMMUNITY SERVICES, Speakers, Automobile Loans
# 5     ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6     ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7     ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8     EDUCATION SERVICES, Library, Libraries, Public...
# 9     EDUCATION SERVICES, Library, Libraries, Public...
# 10    EDUCATION SERVICES, Library, Libraries, Public...
# 11    EDUCATION SERVICES, Adult, Alternative, Litera...
# 12    EDUCATION SERVICES, Library, Libraries, Public...
# 13    COMMUNITY SERVICES, Interpretation/Translation...
# 14    ALCOHOLISM SERVICES, Residential Care, DRUG AB...
# 15    COMMODITY SERVICES, Clothing/Personal Items, C...
# 16    COMMODITY SERVICES, Clothing/Personal Items, C...
# ...

# %%
a = df["name"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df1 = df["name" ,'location_id','id' ] #Not return output beacuse more than once columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\IMNimish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\IMNimish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\IMNimish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'location_id', 'id')
#
# ...

# %%
df[["name" ,'location_id','id' ]] #when have more than one columns, need to enclosed with in squre bracket like [[]].
# Out:
#                                     name  location_id  id
# 0        Fair Oaks Adult Activity Center            1   1
# 1       Second Career Employment Program            2   2
# 2                 Senior Peer Counseling            3   3
# 3               Family Visitation Center            4   4
# 4      Economic Self-Sufficiency Program            5   5
# 5   Little House Recreational Activities            6   6
# 6       Rosener House Adult Day Services            7   7
# 7         Meals on Wheels - South County            8   8
# 8                       Fair Oaks Branch            9   9
# 9                           Main Library           10  10
# 10                       Schaberg Branch           11  11
# 11                          Project Read           12  12
# 12                 Redwood Shores Branch           13  13
# 13                    Redwood City Corps           14  14
# 14           Adult Rehabilitation Center           15  15
# ...

# %%
df1 = df[["name" ,'location_id','id' ]]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive E is Media
#  Volume Serial Number is 7293-E2F1
#
#  Directory of e:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook
#
# 05/04/2023  04:30 PM    <DIR>          .
# 05/04/2023  04:30 PM    <DIR>          ..
# 05/04/2023  05:13 PM           339,554 FSDS_1.0_Pandas_Day1_262.ipynb
# 05/04/2023  04:30 PM    <DIR>          Resources
# 04/26/2023  03:23 PM            14,618 taxonomy.csv
# 05/01/2023  03:20 PM       574,072,999 zomato.csv
#                3 File(s)    574,427,171 bytes
#                3 Dir(s)  154,677,379,072 bytes free

# %%
import pandas as pd
pd.read_excel("E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\LUSID Excel - Manage Orders.xlsx")
# Out:
#     Unnamed: 0                                   Unnamed: 1
# 0          NaN  This sheet allows you to manage executions:  \
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0                 NaN        NaN        NaN        NaN        NaN        NaN  \
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_excel('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\LUSID Excel - Manage Orders.xlsx',sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2
# 0          NaN  This sheet allows you to manage Allocations:              NaN  \
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df = pd.ExcelFile('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
pd.read_excel('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\LUSID Excel - Manage Orders.xlsx',sheet_name = "Blocks")
# Out:
#     Unnamed: 0                               Unnamed: 1
# 0          NaN  This sheet allows you to manage Blocks:  \
# 1          NaN                            1. ListBlocks
# 2          NaN                              2. GetBlock
# 3          NaN                          3. UpsertBlocks
# 4          NaN                                      NaN
# 5          NaN                                      NaN
# 6          NaN                                      NaN
# 7          NaN                                      NaN
# 8          NaN                  1. Get a list of blocks
# 9          NaN                                      NaN
# 10         NaN                                    asAt:
# 11         NaN                                      NaN
# 12         NaN                                  filter:
# 13         NaN                                      NaN
# 14         NaN                            propertyKeys:
# 15         NaN                                      NaN
# ...

# %%
for i in df.sheet_names:
    pd.read_excel('E:\FSDS 2.0\FSDS-Bootcamp-2.0\Class Notebook\Resources\LUSID Excel - Manage Orders.xlsx' , sheet_name=i)

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv')
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...

# %%
a = pd.read_csv('zomato.csv')

# %%
a.head(2)
# Out:
#                                                  url
# 0  https://www.zomato.com/bangalore/jalsa-banasha...  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233  \
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type
# 0  Banashankari  Casual Dining  \
# 1  Banashankari  Casual Dining
#
#                                           dish_liked
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...  \
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)
# ...
