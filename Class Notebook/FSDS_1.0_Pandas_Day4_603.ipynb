# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1,thresh=800) #Require that many non-NA values if availble then drop further values.
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 3, 6, 10, 11, 21, 23, 27, 52, 54, 62, 66, 75, 88, 92, 96, 97, 102, 110, 118, 123, 124, 136, 137, 139, 148, 151, 170, 174, 177, 183, 193, 194, 195, 205, 209, 215, 218, 224, 230, 245, 248, 251, 252, 257, 262, 263, 268, 269, 273, 275, 291, 292, 297, 299, 305, 307, 309, 310, 311, 318, 319, 325, 327, 329, 331, 332, 336, 337, 339, 340, 341, 345, 356, 366, 369, 370, 377, 390, 393, 394, 412, 429, 430, 434, 435, 438, 445, 449, 452, 453, 456, 460, 462, 473, 484, 486, 487, 492, 496, ...]
#
# [183 rows x 0 columns]

# %%
df.dropna(axis=0,how='all')
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value='nimish')
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId
#                count        mean         std  min    25%    50%    75%    max
# Survived
# 0               60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0  \
# 1              123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0
#
#          Pclass            ... Parch        Fare
#           count      mean  ...   75%  max  count       mean        std   min
# Survived                   ...
# 0          60.0  1.216667  ...   1.0  4.0   60.0  64.048262  61.693457  0.00  \
# 1         123.0  1.178862  ...   1.0  2.0  123.0  85.821107  81.843522  8.05
#
#
#             25%      50%   75%       max
# Survived
# 0         27.45  45.3104  79.2  263.0000
# 1         30.50  69.3000  93.5  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min    25%    50%    75%    max
# Survived
# 0          60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0
# 1         123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0

# %%
df.groupby('Survived').describe()['Fare']
# Out:
#           count       mean        std   min    25%      50%   75%       max
# Survived
# 0          60.0  64.048262  61.693457  0.00  27.45  45.3104  79.2  263.0000
# 1         123.0  85.821107  81.843522  8.05  30.50  69.3000  93.5  512.3292

# %%
df.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count      60.000000  123.000000
# mean      402.983333  480.918699
# std       252.917183  241.058955
# min         7.000000    2.000000
# 25%       174.000000  309.000000
# 50%       359.000000  497.000000
# 75%       634.500000  690.500000
# max       873.000000  890.000000

# %%
df1 = pd.read_csv('E:\\FSDS 2.0\\FSDS-Bootcamp-2.0\\Class Notebook\\Resources\\bank.csv', sep=";")

# %%
df1.head(20)
# Out:
#     age            job  marital  education default  balance housing loan
# 0    30     unemployed  married    primary      no     1787      no   no  \
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# ...

# %%
l = []
for i in df1['education'].unique() : 
    l.append(df1[df1["education"]  == i])

# %%
df2 = l[0]

# %%
df2
# Out:
#       age            job   marital education default  balance housing loan
# 0      30     unemployed   married   primary      no     1787      no   no  \
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df3 = l[1]

# %%
df3
# Out:
#       age          job  marital  education default  balance housing loan
# 1      33     services  married  secondary      no     4789     yes  yes  \
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df3
# Out:
#       age          job  marital  education default  balance housing loan
# 1      33     services  married  secondary      no     4789     yes  yes  \
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
"Nimish" + "Gaikwad"
# Out:
# 'NimishGaikwad'

# %%
pd.concat([df2,df3])
# Out:
#       age          job   marital  education default  balance housing loan
# 0      30   unemployed   married    primary      no     1787      no   no  \
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df2 = df2.head()

# %%
df2
# Out:
#     age          job   marital education default  balance housing loan
# 0    30   unemployed   married   primary      no     1787      no   no  \
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
df3 = df3.head()

# %%
df3
# Out:
#     age          job  marital  education default  balance housing loan
# 1    33     services  married  secondary      no     4789     yes  yes  \
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
pd.concat([df2,df3])
# Out:
#     age          job   marital  education default  balance housing loan
# 0    30   unemployed   married    primary      no     1787      no   no  \
# 9    43     services   married    primary      no      -88     yes  yes
# 18   25  blue-collar    single    primary      no     -221     yes   no
# 26   55  blue-collar   married    primary      no      627     yes   no
# 36   78      retired  divorced    primary      no      229      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# 7    39   technician   married  secondary      no      147     yes   no
# 10   39     services   married  secondary      no     9374     yes   no
# 11   43       admin.   married  secondary      no      264     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# ...

# %%
df2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df2 = df2.head()[['age','job','marital']]

# %%
df3 = df3.head()[['age', 'job', 'marital']]

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df5 = pd.concat([df2,df3],axis=1)

# %%
df5
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 9   43.0     services   married   NaN          NaN      NaN
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married

# %%
df5['age']
# Out:
#      age   age
# 0   30.0   NaN
# 9   43.0   NaN
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 10   NaN  39.0
# 11   NaN  43.0

# %%
df5.iloc[: ,3] #iloc integer location it will filterout rows and coloums it take rows value 1st place and coloums value 2nd place
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
df5.iloc[[4,5],[3,4]] #iloc always take default indexs
# Out:
#      age       job
# 36   NaN       NaN
# 1   33.0  services

# %%
df5.loc[[9,10] , ['age']] #loc always takes named one
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18]]
# Out:
#     age          job  marital
# 9    43     services  married
# 18   25  blue-collar   single

# %%
df2.loc[[9,18] , ['job' , 'marital']]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.iloc[[1,2] , [1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18] , ['age' , 'marital']]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
pd.merge(df2,df3,on='age')
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df2,df3,on='age',how='left')
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
pd.merge(df2,df3,on='age',how='right')
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
pd.merge(df2,df3,on='age',how='outer')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df2.join(df3,on='age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 df2.join(df3,on='age')
#
# File c:\Users\IMNimish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9734, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9571 def join(
#    9572     self,
#    9573     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9579     validate: str | None = None,
#    9580 ) -> DataFrame:
#    9581     """
#    9582     Join columns of another DataFrame.
#    9583
#    (...)
#    9732     5  K1  A5   B1
#    9733     """
# -> 9734     return self._join_compat(
#    9735         other,
#    9736         on=on,
#    9737         how=how,
#    9738         lsuffix=lsuffix,
#    9739         rsuffix=rsuffix,
#    9740         sort=sort,
#    9741         validate=validate,
#    9742     )
#
# ...

# %%
df2 = df2.set_index('age')

# %%
df2
# Out:
#              job   marital
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3 = df3.set_index('age')

# %%
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df2.join(df3)
#
# File c:\Users\IMNimish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9734, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9571 def join(
#    9572     self,
#    9573     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9579     validate: str | None = None,
#    9580 ) -> DataFrame:
#    9581     """
#    9582     Join columns of another DataFrame.
#    9583
#    (...)
#    9732     5  K1  A5   B1
#    9733     """
# -> 9734     return self._join_compat(
#    9735         other,
#    9736         on=on,
#    9737         how=how,
#    9738         lsuffix=lsuffix,
#    9739         rsuffix=rsuffix,
#    9740         sort=sort,
#    9741         validate=validate,
#    9742     )
#
# ...

# %%
df2.rename(columns={'job' : 'job1',"marital" : 'marital1'},inplace=True)

# %%
df2
# Out:
#             job1  marital1
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3 ) #by default left
# Out:
#             job1  marital1     job  marital
# age
# 25   blue-collar    single     NaN      NaN
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df2.join(df3 ,how = 'inner')
# Out:
#          job1 marital1     job  marital
# age
# 43   services  married  admin.  married

# %%
pd.merge(df2,df3)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 pd.merge(df2,df3)
#
# File c:\Users\IMNimish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:144, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     127 @Substitution("\nleft : DataFrame or named Series")
#     128 @Appender(_merge_doc, indents=0)
#     129 def merge(
#    (...)
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#     147         how=how,
#     148         on=on,
#     149         left_on=left_on,
#     150         right_on=right_on,
#     151         left_index=left_index,
#     152         right_index=right_index,
#     153         sort=sort,
# ...

# %%
pd.merge(df2,df3,left_on='job1' , right_on='job')
# Out:
#           job1 marital1          job  marital
# 0     services  married     services  married
# 1     services  married     services  married
# 2  blue-collar   single  blue-collar  married
# 3  blue-collar  married  blue-collar  married

# %%
df2
# Out:
#             job1  marital1
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
pd.merge(df3.reset_index() , df2.reset_index())
# Out:
#    age     job  marital      job1 marital1
# 0   43  admin.  married  services  married

# %%
df2.join(df3)
# Out:
#             job1  marital1     job  marital
# age
# 25   blue-collar    single     NaN      NaN
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df3= df3.reset_index()

# %%
df3
# Out:
#    age          job  marital
# 0   33     services  married
# 1   59  blue-collar  married
# 2   39   technician  married
# 3   39     services  married
# 4   43       admin.  married

# %%
df3.age
# Out:
# 0    33
# 1    59
# 2    39
# 3    39
# 4    43
# Name: age, dtype: int64

# %%
df3['age']
# Out:
# 0    33
# 1    59
# 2    39
# 3    39
# 4    43
# Name: age, dtype: int64
