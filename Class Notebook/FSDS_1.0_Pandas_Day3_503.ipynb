# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 887          888         1       1              Graham, Miss. Margaret Edith  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
s = pd.Series([1,2,3])

# %%
s.describe()
# Out:
# count    3.0
# mean     2.0
# std      1.0
# min      1.0
# 25%      1.5
# 50%      2.0
# 75%      2.5
# max      3.0
# dtype: float64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
col_name = df.dtypes[df.dtypes == "object"].index

# %%
l = [4,5,6,7,8,8,9,0,'nimish','gaikwad']

# %%
l[0]
# Out:
# 4

# %%
l[l == 8]
# Out:
# 4

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['new_col'] = "Nimish"

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col
# 0        0         A/5 21171   7.2500   NaN        S  Nimish
# 1        0          PC 17599  71.2833   C85        C  Nimish
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Nimish
# 3        0            113803  53.1000  C123        S  Nimish
# 4        0            373450   8.0500   NaN        S  Nimish
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S  Nimish
# 887      0            112053  30.0000   B42        S  Nimish
# 888      2        W./C. 6607  23.4500   NaN        S  Nimish
# 889      0            111369  30.0000  C148        C  Nimish
# 890      0            370376   7.7500   NaN        Q  Nimish
#
# [891 rows x 13 columns]

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Name"][0:8]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# Name: Name, dtype: object

# %%
df['Name'][0:8:2]
# Out:
# 0     Braund, Mr. Owen Harris
# 2      Heikkinen, Miss. Laina
# 4    Allen, Mr. William Henry
# 6     McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col
# 0        0         A/5 21171   7.2500   NaN        S  Nimish
# 1        0          PC 17599  71.2833   C85        C  Nimish
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Nimish
# 3        0            113803  53.1000  C123        S  Nimish
# 4        0            373450   8.0500   NaN        S  Nimish
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S  Nimish
# 887      0            112053  30.0000   B42        S  Nimish
# 888      2        W./C. 6607  23.4500   NaN        S  Nimish
# 889      0            111369  30.0000  C148        C  Nimish
# 890      0            370376   7.7500   NaN        Q  Nimish
#
# [891 rows x 13 columns]

# %%
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 5              6         0       3                          Moran, Mr. James  \
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked new_col
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  Nimish
# 17     male  NaN      0      0      244373  13.0000   NaN        S  Nimish
# 19   female  NaN      0      0        2649   7.2250   NaN        C  Nimish
# 26     male  NaN      0      0        2631   7.2250   NaN        C  Nimish
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  Nimish
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  Nimish
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  Nimish
# 868    male  NaN      0      0      345777   9.5000   NaN        S  Nimish
# 878    male  NaN      0      0      349217   7.8958   NaN        S  Nimish
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  Nimish
#
# [177 rows x 13 columns]

# %%
ind = df[df['Age'].isnull() == True].index

# %%
ind
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
len(df[df['Age'].isnull() == True].index)
# Out:
# 177

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 5              6         0       3                          Moran, Mr. James  \
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked new_col
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  Nimish
# 17     male  NaN      0      0      244373  13.0000   NaN        S  Nimish
# 19   female  NaN      0      0        2649   7.2250   NaN        C  Nimish
# 26     male  NaN      0      0        2631   7.2250   NaN        C  Nimish
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  Nimish
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  Nimish
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  Nimish
# 868    male  NaN      0      0      345777   9.5000   NaN        S  Nimish
# 878    male  NaN      0      0      349217   7.8958   NaN        S  Nimish
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  Nimish
#
# [177 rows x 13 columns]

# %%
df.iloc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 5              6         0       3                          Moran, Mr. James  \
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked new_col
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  Nimish
# 17     male  NaN      0      0      244373  13.0000   NaN        S  Nimish
# 19   female  NaN      0      0        2649   7.2250   NaN        C  Nimish
# 26     male  NaN      0      0        2631   7.2250   NaN        C  Nimish
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  Nimish
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  Nimish
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  Nimish
# 868    male  NaN      0      0      345777   9.5000   NaN        S  Nimish
# 878    male  NaN      0      0      349217   7.8958   NaN        S  Nimish
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  Nimish
#
# [177 rows x 13 columns]

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 5              6         0       3                          Moran, Mr. James  \
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked new_col
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  Nimish
# 17     male  NaN      0      0      244373  13.0000   NaN        S  Nimish
# 19   female  NaN      0      0        2649   7.2250   NaN        C  Nimish
# 26     male  NaN      0      0        2631   7.2250   NaN        C  Nimish
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  Nimish
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  Nimish
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  Nimish
# 868    male  NaN      0      0      345777   9.5000   NaN        S  Nimish
# 878    male  NaN      0      0      349217   7.8958   NaN        S  Nimish
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  Nimish
#
# [177 rows x 13 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron
# 0        0         A/5 21171   7.2500   NaN        S    sudh
# 1        0          PC 17599  71.2833   C85        C    sudh
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sudh
# 3        0            113803  53.1000  C123        S    sudh
# 4        0            373450   8.0500   NaN        S    sudh
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    sudh
# 887      0            112053  30.0000   B42        S    sudh
# 888      2        W./C. 6607  23.4500   NaN        S    sudh
# 889      0            111369  30.0000  C148        C    sudh
# 890      0            370376   7.7500   NaN        Q    sudh
#
# [891 rows x 13 columns]

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name
# 258          259         1       1                    Ward, Miss. Anna  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C  \
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     new_col
# 258  Nimish
# 679  Nimish
# 737  Nimish

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron
# 0      0         A/5 21171   7.2500   NaN        S    sudh
# 1      0          PC 17599  71.2833   C85        C    sudh
# 2      0  STON/O2. 3101282   7.9250   NaN        S    sudh
# 3      0            113803  53.1000  C123        S    sudh
# 4      0            373450   8.0500   NaN        S    sudh

# %%
dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

pd.read_csv('E:\\Downloads\\bank\\bank.csv' , sep=";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %% [markdown]
# ```markdown
# 1 .how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .
#
#
#  https://codeshare.io/X8PY8Y
#
# ```

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron
# 0        0         A/5 21171   7.2500   NaN        S    sudh
# 1        0          PC 17599  71.2833   C85        C    sudh
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sudh
# 3        0            113803  53.1000  C123        S    sudh
# 4        0            373450   8.0500   NaN        S    sudh
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    sudh
# 887      0            112053  30.0000   B42        S    sudh
# 888      2        W./C. 6607  23.4500   NaN        S    sudh
# 889      0            111369  30.0000  C148        C    sudh
# 890      0            370376   7.7500   NaN        Q    sudh
#
# [891 rows x 13 columns]

# %%
df["dsfdsafsafa"] = "dfsfdsa"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron dsfdsafsafa
# 0        0         A/5 21171   7.2500   NaN        S    sudh     dfsfdsa
# 1        0          PC 17599  71.2833   C85        C    sudh     dfsfdsa
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sudh     dfsfdsa
# 3        0            113803  53.1000  C123        S    sudh     dfsfdsa
# 4        0            373450   8.0500   NaN        S    sudh     dfsfdsa
# ..     ...               ...      ...   ...      ...     ...         ...
# 886      0            211536  13.0000   NaN        S    sudh     dfsfdsa
# 887      0            112053  30.0000   B42        S    sudh     dfsfdsa
# 888      2        W./C. 6607  23.4500   NaN        S    sudh     dfsfdsa
# 889      0            111369  30.0000  C148        C    sudh     dfsfdsa
# 890      0            370376   7.7500   NaN        Q    sudh     dfsfdsa
#
# [891 rows x 14 columns]

# %%
bank = pd.read_csv('E:\\FSDS 2.0\\FSDS-Bootcamp-2.0\\Class Notebook\\Resources\\bank.csv',sep= ";")

# %%
bank
# Out:
#       age            job  marital  education default  balance housing loan
# 0      30     unemployed  married    primary      no     1787      no   no  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %% [markdown]
# # # **Class Task 1**

# %% [markdown]
# ```markdown
# 1 .Find out how many male and female passenger was onboarded .
# 2. how many survived we have .
# 3. how many casuality we have
# 4 . what is name of a person who is the eldest one .
# 5 . how many passenger do we have in first , second and third class
# 6. how many person we have whose name starts with "s"
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .
#
# ```

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col
# 0        0         A/5 21171   7.2500   NaN        S  Nimish
# 1        0          PC 17599  71.2833   C85        C  Nimish
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Nimish
# 3        0            113803  53.1000  C123        S  Nimish
# 4        0            373450   8.0500   NaN        S  Nimish
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S  Nimish
# 887      0            112053  30.0000   B42        S  Nimish
# 888      2        W./C. 6607  23.4500   NaN        S  Nimish
# 889      0            111369  30.0000  C148        C  Nimish
# 890      0            370376   7.7500   NaN        Q  Nimish
#
# [891 rows x 13 columns]

# %%
#1 .Find out how many male and female passenger was onboarded.

df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#2. how many survived we have .

df['Survived'].value_counts()[1]
# Out:
# 342

# %%
#3. how many casuality we have 
df['Embarked'].value_counts()['C']
# Out:
# 168

# %%
#4 . what is name of a person who is the eldest one . 

df.loc[df['Age'].idxmax(),['Name', 'Age']]
# Out:
# Name    Barkworth, Mr. Algernon Henry Wilson
# Age                                     80.0
# Name: 630, dtype: object

# %%
df[df['Age'] == max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
#5 . how many passenger do we have in first , second and third class 

df['Pclass'].value_counts().sort_index().rename({1:'First Class', 2 : 'Secound Class', 3 :'Third Class'})
# Out:
# Pclass
# First Class      216
# Secound Class    184
# Third Class      491
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()[:1]
# Out:
# Pclass
# 3    491
# Name: count, dtype: int64

# %%
#6. how many person we have whose name starts with "s"

df[df['Name'].str.lower().str.startswith('s')]['Name'].count()
# Out:
# 86

# %%
#7. try to create a new column which is a summation  of "SibSp" and "parch"

df['new_col2'] = "SibSp" 
df['new_col3'] = "parch"
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col new_col2 new_col3
# 0        0         A/5 21171   7.2500   NaN        S  Nimish    SibSp    parch
# 1        0          PC 17599  71.2833   C85        C  Nimish    SibSp    parch
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Nimish    SibSp    parch
# 3        0            113803  53.1000  C123        S  Nimish    SibSp    parch
# 4        0            373450   8.0500   NaN        S  Nimish    SibSp    parch
# ..     ...               ...      ...   ...      ...     ...      ...      ...
# 886      0            211536  13.0000   NaN        S  Nimish    SibSp    parch
# 887      0            112053  30.0000   B42        S  Nimish    SibSp    parch
# 888      2        W./C. 6607  23.4500   NaN        S  Nimish    SibSp    parch
# 889      0            111369  30.0000  C148        C  Nimish    SibSp    parch
# 890      0            370376   7.7500   NaN        Q  Nimish    SibSp    parch
#
# [891 rows x 15 columns]

# %%
#8 . how many person do we have below age of 25 .

df[df['Age'] < 25]['Age'].count()
# Out:
# 278

# %%
#9 . how many person died whose age was less then 40 

df[(df['Survived'] == 0) & (df['Age'] < 40)]['Age'].count()
# Out:
# 322

# %%
#10 . from a  cabin column seperate text and numeric value . 

df['CabinLetter'] = df['Cabin'].str.extract('([A-Za-z]+)', expand=False)
df['CabinNumber'] = df['Cabin'].str.extract('(\d+)', expand=False)

# %%
df['Cabin'].str.extract('([A-Za-z]+)', expand=False)
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'].str.extract('(\d+)', expand=False)
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col new_col2
# 0        0         A/5 21171   7.2500   NaN        S  Nimish    SibSp  \
# 1        0          PC 17599  71.2833   C85        C  Nimish    SibSp
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Nimish    SibSp
# 3        0            113803  53.1000  C123        S  Nimish    SibSp
# 4        0            373450   8.0500   NaN        S  Nimish    SibSp
# ..     ...               ...      ...   ...      ...     ...      ...
# 886      0            211536  13.0000   NaN        S  Nimish    SibSp
# 887      0            112053  30.0000   B42        S  Nimish    SibSp
# 888      2        W./C. 6607  23.4500   NaN        S  Nimish    SibSp
# 889      0            111369  30.0000  C148        C  Nimish    SibSp
# 890      0            370376   7.7500   NaN        Q  Nimish    SibSp
#
#     new_col3 CabinLetter CabinNumber
# 0      parch         NaN         NaN
# 1      parch           C          85
# 2      parch         NaN         NaN
# 3      parch           C         123
# 4      parch         NaN         NaN
# ..       ...         ...         ...
# 886    parch         NaN         NaN
# 887    parch           B          42
# 888    parch         NaN         NaN
# 889    parch           C         148
# 890    parch         NaN         NaN
#
# [891 rows x 17 columns]

# %%
df['CabinLetter'] = df['Cabin'].str.extract('([A-Za-z]+)', expand=True)
df['CabinNumber'] = df['Cabin'].str.extract('(\d+)', expand=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col new_col2
# 0        0         A/5 21171   7.2500   NaN        S  Nimish    SibSp  \
# 1        0          PC 17599  71.2833   C85        C  Nimish    SibSp
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Nimish    SibSp
# 3        0            113803  53.1000  C123        S  Nimish    SibSp
# 4        0            373450   8.0500   NaN        S  Nimish    SibSp
# ..     ...               ...      ...   ...      ...     ...      ...
# 886      0            211536  13.0000   NaN        S  Nimish    SibSp
# 887      0            112053  30.0000   B42        S  Nimish    SibSp
# 888      2        W./C. 6607  23.4500   NaN        S  Nimish    SibSp
# 889      0            111369  30.0000  C148        C  Nimish    SibSp
# 890      0            370376   7.7500   NaN        Q  Nimish    SibSp
#
#     new_col3 CabinLetter CabinNumber
# 0      parch         NaN         NaN
# 1      parch           C          85
# 2      parch         NaN         NaN
# 3      parch           C         123
# 4      parch         NaN         NaN
# ..       ...         ...         ...
# 886    parch         NaN         NaN
# 887    parch           B          42
# 888    parch         NaN         NaN
# 889    parch           C         148
# 890    parch         NaN         NaN
#
# [891 rows x 17 columns]

# %% [markdown]
# # **Class Task 2**

# %% [markdown]
# ```markdown
# 1 .how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .
#
#
#  https://codeshare.io/X8PY8Y
#
# ```

# %%
#1 .how many campaign available in this dataset . 

bank['campaign'].count()
# Out:
# 4521

# %%
#2 . how many users do we have with housing and personal loan . 

#housing_c = bank[(bank['housing'] == 'yes') & (bank['loan'] == 'yes')]['housing'].count()

#personal_loan= bank[(bank['housing'] == 'yes') & (bank['loan'] == 'yes')]['loan'].count()

#bank[(bank['housing'] == 'yes') & (bank['loan'] == 'yes')].shape[0]

len(bank[(bank['housing'] == 'yes') & (bank['loan'] == 'yes')])
# Out:
# 406

# %%
bank.housing[bank.loan == 'yes'].value_counts()
# Out:
# housing
# yes    406
# no     285
# Name: count, dtype: int64

# %%
#3. how many person do we have whose age is 60+ .

bank[(bank['age'] >= 60)]['age'].count()
# Out:
# 174

# %%
bank.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
#4 . in which month we have trageted most of the customer . 

targeted_month= bank['month'].value_counts().idxmax()

print('The most targeted month is:', targeted_month)
# Out:
# The most targeted month is: may

# %%
#5 . which mode of call is giving you more result

mode_of_call = bank['contact'].value_counts().idxmax()

print('Mode of call is giving you more result :', mode_of_call)
# Out:
# Mode of call is giving you more result : cellular

# %%
#6 . how many enterpeures do we have in this list  

entrepreneur_count = bank[(bank['job'] == 'entrepreneur')]['job'].count()

print(f'we have {entrepreneur_count} entrepreneur')
# Out:
# we have 168 entrepreneur

# %%
#7 . how many customers do we have with negative balance 

bank[(bank['balance'] < 0)]['balance'].count()
# Out:
# 366

# %%
bank[bank['balance'] < 0]['balance'].count()
# Out:
# 366

# %%
#8. prepare a group of data based on education level . 

bank.groupby(['education'])['education'].value_counts()
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# Name: count, dtype: int64

# %%
bank.groupby('education').size()
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# dtype: int64
